# %%
from binance.exceptions import BinanceAPIException
import os
# from binance import AsyncClient
from binance.client import Client
import json
import requests
import pandas as pd

# %%
# Binance
api_key = os.environ.get('binance_api')
api_secret = os.environ.get('binance_secret')

# Telegram
telegramToken = os.environ.get('telegramToken') 
telegram_chat_id = os.environ.get('telegram_chat_id')

# %%
# %%
def sendTelegramMessage(emoji, msg):
    if not emoji:
        lmsg = msg
    else:
        lmsg = emoji+" "+msg
    url = f"https://api.telegram.org/bot{telegramToken}/sendMessage?chat_id={telegram_chat_id}&text={lmsg}"
    requests.get(url).json() # this sends the message

def sendTelegramAlert(emoji, date, coin, timeframe, strategy, ordertype, value, amount):
    lmsg = emoji + " " + str(date) + " - " + coin + " - " + strategy + " - " + timeframe + " - " + ordertype + " - " + "Value: " + str(value) + " - " + "Amount: " + str(amount)
    url = f"https://api.telegram.org/bot{telegramToken}/sendMessage?chat_id={telegram_chat_id}&text={lmsg}"
    requests.get(url).json() # this sends the message

# %%
# Binance Client
clientTest = Client(api_key, api_secret)

# %%
tickers = clientTest.get_ticker()

# %%
tickers
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '0.00168200',
#   'priceChangePercent': '2.434',
#   'weightedAvgPrice': '0.06975689',
#   'prevClosePrice': '0.06911600',
#   'lastPrice': '0.07079700',
#   'lastQty': '3.29700000',
#   'bidPrice': '0.07079600',
#   'bidQty': '14.95160000',
#   'askPrice': '0.07079700',
#   'askQty': '7.09270000',
#   'openPrice': '0.06911500',
#   'highPrice': '0.07112000',
#   'lowPrice': '0.06908800',
#   'volume': '83544.93570000',
#   'quoteVolume': '5827.83458055',
#   'openTime': 1666621760630,
#   'closeTime': 1666708160630,
#   'firstId': 383165931,
#   'lastId': 383346877,
#   'count': 180947},
#  {'symbol': 'LTCBTC',
#   'priceChange': '0.00000900',
#   'priceChangePercent': '0.330',
#   'weightedAvgPrice': '0.00272275',
#   'prevClosePrice': '0.00272800',
#   'lastPrice': '0.00273700',
#   'lastQty': '0.43600000',
#   'bidPrice': '0.00273600',
#   'bidQty': '6.56100000',
#   'askPrice': '0.00273700',
#   'askQty': '67.17600000',
#   'openPrice': '0.00272800',
#   'highPrice': '0.00274200',
#   'lowPrice': '0.00270800',
#   'volume': '44030.36300000',
#   'quoteVolume': '119.88358810',
#   'openTime': 1666621757992,
#   'closeTime': 1666708157992,
#   'firstId': 84396764,
#   'lastId': 84409662,
#   'count': 12899},
#  {'symbol': 'BNBBTC',
#   'priceChange': '0.00008700',
#   'priceChangePercent': '0.615',
#   'weightedAvgPrice': '0.01416822',
#   'prevClosePrice': '0.01415000',
#   'lastPrice': '0.01423700',
#   'lastQty': '5.34300000',
#   'bidPrice': '0.01423600',
#   'bidQty': '34.77300000',
#   'askPrice': '0.01423700',
#   'askQty': '15.59400000',
#   'openPrice': '0.01415000',
#   'highPrice': '0.01425000',
#   'lowPrice': '0.01410400',
#   'volume': '24419.43800000',
#   'quoteVolume': '345.97987705',
#   'openTime': 1666621755918,
#   'closeTime': 1666708155918,
#   'firstId': 206251441,
#   'lastId': 206292336,
#   'count': 40896},
#  {'symbol': 'NEOBTC',
#   'priceChange': '0.00000600',
#   'priceChangePercent': '1.405',
#   'weightedAvgPrice': '0.00042740',
#   'prevClosePrice': '0.00042700',
#   'lastPrice': '0.00043300',
#   'lastQty': '0.49000000',
#   'bidPrice': '0.00043200',
#   'bidQty': '430.50000000',
#   'askPrice': '0.00043300',
#   'askQty': '347.56000000',
#   'openPrice': '0.00042700',
#   'highPrice': '0.00043400',
#   'lowPrice': '0.00042100',
#   'volume': '29321.44000000',
#   'quoteVolume': '12.53201760',
#   'openTime': 1666621755814,
#   'closeTime': 1666708155814,
#   'firstId': 43953473,
#   'lastId': 43955258,
#   'count': 1786},
#  {'symbol': 'QTUMETH',
#   'priceChange': '-0.00002400',
#   'priceChangePercent': '-1.201',
#   'weightedAvgPrice': '0.00199430',
#   'prevClosePrice': '0.00200500',
#   'lastPrice': '0.00197500',
#   'lastQty': '75.30000000',
#   'bidPrice': '0.00197100',
#   'bidQty': '40.70000000',
#   'askPrice': '0.00197700',
#   'askQty': '192.40000000',
#   'openPrice': '0.00199900',
#   'highPrice': '0.00202100',
#   'lowPrice': '0.00196600',
#   'volume': '1843.50000000',
#   'quoteVolume': '3.67648460',
#   'openTime': 1666621759594,
#   'closeTime': 1666708159594,
#   'firstId': 5336528,
#   'lastId': 5336619,
#   'count': 92},
#  {'symbol': 'EOSETH',
#   'priceChange': '-0.00002800',
#   'priceChangePercent': '-3.496',
#   'weightedAvgPrice': '0.00079355',
#   'prevClosePrice': '0.00080200',
#   'lastPrice': '0.00077300',
#   'lastQty': '7.40000000',
#   'bidPrice': '0.00077300',
#   'bidQty': '1813.80000000',
#   'askPrice': '0.00077400',
#   'askQty': '1.50000000',
#   'openPrice': '0.00080100',
#   'highPrice': '0.00080400',
#   'lowPrice': '0.00077000',
#   'volume': '93426.90000000',
#   'quoteVolume': '74.13915950',
#   'openTime': 1666621757880,
#   'closeTime': 1666708157880,
#   'firstId': 23311337,
#   'lastId': 23311922,
#   'count': 586},
#  {'symbol': 'SNTETH',
#   'priceChange': '-0.00000008',
#   'priceChangePercent': '-0.390',
#   'weightedAvgPrice': '0.00002066',
#   'prevClosePrice': '0.00002051',
#   'lastPrice': '0.00002044',
#   'lastQty': '300.00000000',
#   'bidPrice': '0.00002042',
#   'bidQty': '5515.00000000',
#   'askPrice': '0.00002046',
#   'askQty': '786.00000000',
#   'openPrice': '0.00002052',
#   'highPrice': '0.00002098',
#   'lowPrice': '0.00002019',
#   'volume': '2949742.00000000',
#   'quoteVolume': '60.94476569',
#   'openTime': 1666621757293,
#   'closeTime': 1666708157293,
#   'firstId': 3745573,
#   'lastId': 3746246,
#   'count': 674},
#  {'symbol': 'BNTETH',
#   'priceChange': '-0.00000800',
#   'priceChangePercent': '-2.532',
#   'weightedAvgPrice': '0.00031450',
#   'prevClosePrice': '0.00031700',
#   'lastPrice': '0.00030800',
#   'lastQty': '23.00000000',
#   'bidPrice': '0.00030800',
#   'bidQty': '288.60000000',
#   'askPrice': '0.00031000',
#   'askQty': '334.70000000',
#   'openPrice': '0.00031600',
#   'highPrice': '0.00031700',
#   'lowPrice': '0.00030800',
#   'volume': '5925.40000000',
#   'quoteVolume': '1.86351140',
#   'openTime': 1666621706468,
#   'closeTime': 1666708106468,
#   'firstId': 2151227,
#   'lastId': 2151263,
#   'count': 37},
#  {'symbol': 'BCCBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.07908100',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'GASBTC',
#   'priceChange': '-0.00000660',
#   'priceChangePercent': '-5.209',
#   'weightedAvgPrice': '0.00012324',
#   'prevClosePrice': '0.00012670',
#   'lastPrice': '0.00012010',
#   'lastQty': '337.00000000',
#   'bidPrice': '0.00011960',
#   'bidQty': '121.00000000',
#   'askPrice': '0.00012000',
#   'askQty': '589.10000000',
#   'openPrice': '0.00012670',
#   'highPrice': '0.00012960',
#   'lowPrice': '0.00011920',
#   'volume': '571538.80000000',
#   'quoteVolume': '70.43798013',
#   'openTime': 1666621760694,
#   'closeTime': 1666708160694,
#   'firstId': 19437397,
#   'lastId': 19447779,
#   'count': 10383},
#  {'symbol': 'BNBETH',
#   'priceChange': '-0.00370000',
#   'priceChangePercent': '-1.808',
#   'weightedAvgPrice': '0.20244193',
#   'prevClosePrice': '0.20480000',
#   'lastPrice': '0.20100000',
#   'lastQty': '1.16300000',
#   'bidPrice': '0.20100000',
#   'bidQty': '11.41300000',
#   'askPrice': '0.20110000',
#   'askQty': '38.64900000',
#   'openPrice': '0.20470000',
#   'highPrice': '0.20480000',
#   'lowPrice': '0.19900000',
#   'volume': '9491.44300000',
#   'quoteVolume': '1921.46602880',
#   'openTime': 1666621759599,
#   'closeTime': 1666708159599,
#   'firstId': 51267812,
#   'lastId': 51280693,
#   'count': 12882},
#  {'symbol': 'BTCUSDT',
#   'priceChange': '283.25000000',
#   'priceChangePercent': '1.473',
#   'weightedAvgPrice': '19333.10326725',
#   'prevClosePrice': '19223.78000000',
#   'lastPrice': '19506.32000000',
#   'lastQty': '0.00054000',
#   'bidPrice': '19505.77000000',
#   'bidQty': '0.00122000',
#   'askPrice': '19506.30000000',
#   'askQty': '0.03404000',
#   'openPrice': '19223.07000000',
#   'highPrice': '19526.17000000',
#   'lowPrice': '19191.15000000',
#   'volume': '191570.02750000',
#   'quoteVolume': '3703643124.56730560',
#   'openTime': 1666621760710,
#   'closeTime': 1666708160710,
#   'firstId': 2016351291,
#   'lastId': 2021243619,
#   'count': 4892329},
#  {'symbol': 'ETHUSDT',
#   'priceChange': '52.52000000',
#   'priceChangePercent': '3.953',
#   'weightedAvgPrice': '1352.04155702',
#   'prevClosePrice': '1328.62000000',
#   'lastPrice': '1381.14000000',
#   'lastQty': '1.74600000',
#   'bidPrice': '1381.14000000',
#   'bidQty': '39.35830000',
#   'askPrice': '1381.15000000',
#   'askQty': '53.91900000',
#   'openPrice': '1328.62000000',
#   'highPrice': '1388.41000000',
#   'lowPrice': '1325.98000000',
#   'volume': '462930.81560000',
#   'quoteVolume': '625901700.71672600',
#   'openTime': 1666621760692,
#   'closeTime': 1666708160692,
#   'firstId': 995625890,
#   'lastId': 996185449,
#   'count': 559560},
#  {'symbol': 'HSRBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00041400',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'OAXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00017780',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00002801',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00577200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ICNETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00166300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00021140',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WTCBTC',
#   'priceChange': '-0.00000032',
#   'priceChangePercent': '-2.292',
#   'weightedAvgPrice': '0.00001372',
#   'prevClosePrice': '0.00001396',
#   'lastPrice': '0.00001364',
#   'lastQty': '3055.00000000',
#   'bidPrice': '0.00001357',
#   'bidQty': '11.00000000',
#   'askPrice': '0.00001364',
#   'askQty': '655.00000000',
#   'openPrice': '0.00001396',
#   'highPrice': '0.00001428',
#   'lowPrice': '0.00001329',
#   'volume': '286213.00000000',
#   'quoteVolume': '3.92601769',
#   'openTime': 1666621758391,
#   'closeTime': 1666708158391,
#   'firstId': 19769100,
#   'lastId': 19770156,
#   'count': 1057},
#  {'symbol': 'WTCETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00023700',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'LRCBTC',
#   'priceChange': '0.00000049',
#   'priceChangePercent': '3.825',
#   'weightedAvgPrice': '0.00001297',
#   'prevClosePrice': '0.00001280',
#   'lastPrice': '0.00001330',
#   'lastQty': '1441.00000000',
#   'bidPrice': '0.00001327',
#   'bidQty': '7261.00000000',
#   'askPrice': '0.00001329',
#   'askQty': '3228.00000000',
#   'openPrice': '0.00001281',
#   'highPrice': '0.00001337',
#   'lowPrice': '0.00001268',
#   'volume': '1515877.00000000',
#   'quoteVolume': '19.66558732',
#   'openTime': 1666621750335,
#   'closeTime': 1666708150335,
#   'firstId': 21114464,
#   'lastId': 21117171,
#   'count': 2708},
#  {'symbol': 'LRCETH',
#   'priceChange': '0.00000232',
#   'priceChangePercent': '1.253',
#   'weightedAvgPrice': '0.00018661',
#   'prevClosePrice': '0.00018589',
#   'lastPrice': '0.00018742',
#   'lastQty': '136.00000000',
#   'bidPrice': '0.00018748',
#   'bidQty': '101.00000000',
#   'askPrice': '0.00018775',
#   'askQty': '1517.00000000',
#   'openPrice': '0.00018510',
#   'highPrice': '0.00018923',
#   'lowPrice': '0.00018256',
#   'volume': '132755.00000000',
#   'quoteVolume': '24.77295953',
#   'openTime': 1666621724942,
#   'closeTime': 1666708124942,
#   'firstId': 4593505,
#   'lastId': 4593700,
#   'count': 196},
#  {'symbol': 'QTUMBTC',
#   'priceChange': '0.00000090',
#   'priceChangePercent': '0.648',
#   'weightedAvgPrice': '0.00013877',
#   'prevClosePrice': '0.00013860',
#   'lastPrice': '0.00013970',
#   'lastQty': '39.70000000',
#   'bidPrice': '0.00013960',
#   'bidQty': '37.00000000',
#   'askPrice': '0.00013990',
#   'askQty': '100.80000000',
#   'openPrice': '0.00013880',
#   'highPrice': '0.00014070',
#   'lowPrice': '0.00013810',
#   'volume': '28316.10000000',
#   'quoteVolume': '3.92951207',
#   'openTime': 1666621758504,
#   'closeTime': 1666708158504,
#   'firstId': 23482860,
#   'lastId': 23483476,
#   'count': 617},
#  {'symbol': 'YOYOBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000008',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'OMGBTC',
#   'priceChange': '0.00000170',
#   'priceChangePercent': '2.109',
#   'weightedAvgPrice': '0.00008134',
#   'prevClosePrice': '0.00008050',
#   'lastPrice': '0.00008230',
#   'lastQty': '167.70000000',
#   'bidPrice': '0.00008230',
#   'bidQty': '116.80000000',
#   'askPrice': '0.00008240',
#   'askQty': '283.40000000',
#   'openPrice': '0.00008060',
#   'highPrice': '0.00008240',
#   'lowPrice': '0.00008040',
#   'volume': '26698.10000000',
#   'quoteVolume': '2.17159507',
#   'openTime': 1666621756303,
#   'closeTime': 1666708156303,
#   'firstId': 25797898,
#   'lastId': 25798686,
#   'count': 789},
#  {'symbol': 'OMGETH',
#   'priceChange': '-0.00000700',
#   'priceChangePercent': '-0.601',
#   'weightedAvgPrice': '0.00116646',
#   'prevClosePrice': '0.00116700',
#   'lastPrice': '0.00115700',
#   'lastQty': '22.30000000',
#   'bidPrice': '0.00116000',
#   'bidQty': '532.00000000',
#   'askPrice': '0.00116300',
#   'askQty': '4.30000000',
#   'openPrice': '0.00116400',
#   'highPrice': '0.00117800',
#   'lowPrice': '0.00115700',
#   'volume': '2627.50000000',
#   'quoteVolume': '3.06486380',
#   'openTime': 1666621564222,
#   'closeTime': 1666707964222,
#   'firstId': 5856280,
#   'lastId': 5856331,
#   'count': 52},
#  {'symbol': 'ZRXBTC',
#   'priceChange': '0.00000034',
#   'priceChangePercent': '2.727',
#   'weightedAvgPrice': '0.00001266',
#   'prevClosePrice': '0.00001245',
#   'lastPrice': '0.00001281',
#   'lastQty': '1418.00000000',
#   'bidPrice': '0.00001278',
#   'bidQty': '4527.00000000',
#   'askPrice': '0.00001280',
#   'askQty': '837.00000000',
#   'openPrice': '0.00001247',
#   'highPrice': '0.00001284',
#   'lowPrice': '0.00001245',
#   'volume': '140465.00000000',
#   'quoteVolume': '1.77886037',
#   'openTime': 1666621760118,
#   'closeTime': 1666708160118,
#   'firstId': 24903400,
#   'lastId': 24903896,
#   'count': 497},
#  {'symbol': 'ZRXETH',
#   'priceChange': '-0.00000010',
#   'priceChangePercent': '-0.055',
#   'weightedAvgPrice': '0.00018199',
#   'prevClosePrice': '0.00018010',
#   'lastPrice': '0.00018040',
#   'lastQty': '84.00000000',
#   'bidPrice': '0.00018050',
#   'bidQty': '3008.00000000',
#   'askPrice': '0.00018080',
#   'askQty': '924.00000000',
#   'openPrice': '0.00018050',
#   'highPrice': '0.00018370',
#   'lowPrice': '0.00018010',
#   'volume': '51376.00000000',
#   'quoteVolume': '9.35005640',
#   'openTime': 1666621744581,
#   'closeTime': 1666708144581,
#   'firstId': 5316635,
#   'lastId': 5316694,
#   'count': 60},
#  {'symbol': 'STRATBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00003085',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'STRATETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00105300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000013',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005306',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00008703',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00126350',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'KNCBTC',
#   'priceChange': '0.00000078',
#   'priceChangePercent': '1.798',
#   'weightedAvgPrice': '0.00004374',
#   'prevClosePrice': '0.00004343',
#   'lastPrice': '0.00004417',
#   'lastQty': '21.50000000',
#   'bidPrice': '0.00004408',
#   'bidQty': '7.10000000',
#   'askPrice': '0.00004418',
#   'askQty': '67.00000000',
#   'openPrice': '0.00004339',
#   'highPrice': '0.00004444',
#   'lowPrice': '0.00004320',
#   'volume': '65066.40000000',
#   'quoteVolume': '2.84609078',
#   'openTime': 1666621755496,
#   'closeTime': 1666708155496,
#   'firstId': 19522270,
#   'lastId': 19523213,
#   'count': 944},
#  {'symbol': 'KNCETH',
#   'priceChange': '-0.00000590',
#   'priceChangePercent': '-0.942',
#   'weightedAvgPrice': '0.00062644',
#   'prevClosePrice': '0.00062740',
#   'lastPrice': '0.00062010',
#   'lastQty': '234.10000000',
#   'bidPrice': '0.00062230',
#   'bidQty': '14.50000000',
#   'askPrice': '0.00062540',
#   'askQty': '29.10000000',
#   'openPrice': '0.00062600',
#   'highPrice': '0.00063590',
#   'lowPrice': '0.00061940',
#   'volume': '13695.30000000',
#   'quoteVolume': '8.57925061',
#   'openTime': 1666621755420,
#   'closeTime': 1666708155420,
#   'firstId': 4691099,
#   'lastId': 4691239,
#   'count': 141},
#  {'symbol': 'FUNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000029',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'FUNETH',
#   'priceChange': '-0.00000017',
#   'priceChangePercent': '-3.114',
#   'weightedAvgPrice': '0.00000539',
#   'prevClosePrice': '0.00000547',
#   'lastPrice': '0.00000529',
#   'lastQty': '56256.00000000',
#   'bidPrice': '0.00000528',
#   'bidQty': '169608.00000000',
#   'askPrice': '0.00000531',
#   'askQty': '88277.00000000',
#   'openPrice': '0.00000546',
#   'highPrice': '0.00000546',
#   'lowPrice': '0.00000528',
#   'volume': '2964378.00000000',
#   'quoteVolume': '15.97263029',
#   'openTime': 1666621758414,
#   'closeTime': 1666708158414,
#   'firstId': 3093229,
#   'lastId': 3093360,
#   'count': 132},
#  {'symbol': 'SNMBTC',
#   'priceChange': '0.00000041',
#   'priceChangePercent': '3.208',
#   'weightedAvgPrice': '0.00001332',
#   'prevClosePrice': '0.00001275',
#   'lastPrice': '0.00001319',
#   'lastQty': '12.00000000',
#   'bidPrice': '0.00001318',
#   'bidQty': '12.00000000',
#   'askPrice': '0.00001321',
#   'askQty': '992.00000000',
#   'openPrice': '0.00001278',
#   'highPrice': '0.00001389',
#   'lowPrice': '0.00001265',
#   'volume': '1218148.00000000',
#   'quoteVolume': '16.22494421',
#   'openTime': 1666621750379,
#   'closeTime': 1666708150379,
#   'firstId': 12009448,
#   'lastId': 12014315,
#   'count': 4868},
#  {'symbol': 'SNMETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004986',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'NEOETH',
#   'priceChange': '-0.00008000',
#   'priceChangePercent': '-1.292',
#   'weightedAvgPrice': '0.00612666',
#   'prevClosePrice': '0.00618000',
#   'lastPrice': '0.00611000',
#   'lastQty': '40.34000000',
#   'bidPrice': '0.00610000',
#   'bidQty': '218.19000000',
#   'askPrice': '0.00611000',
#   'askQty': '61.23000000',
#   'openPrice': '0.00619000',
#   'highPrice': '0.00622000',
#   'lowPrice': '0.00602000',
#   'volume': '11954.12000000',
#   'quoteVolume': '73.23882250',
#   'openTime': 1666621760361,
#   'closeTime': 1666708160361,
#   'firstId': 10966214,
#   'lastId': 10966967,
#   'count': 754},
#  {'symbol': 'IOTABTC',
#   'priceChange': '0.00000016',
#   'priceChangePercent': '1.263',
#   'weightedAvgPrice': '0.00001284',
#   'prevClosePrice': '0.00001265',
#   'lastPrice': '0.00001283',
#   'lastQty': '1553.00000000',
#   'bidPrice': '0.00001280',
#   'bidQty': '2461.00000000',
#   'askPrice': '0.00001283',
#   'askQty': '2864.00000000',
#   'openPrice': '0.00001267',
#   'highPrice': '0.00001293',
#   'lowPrice': '0.00001267',
#   'volume': '310347.00000000',
#   'quoteVolume': '3.98475657',
#   'openTime': 1666621737169,
#   'closeTime': 1666708137169,
#   'firstId': 33678221,
#   'lastId': 33678993,
#   'count': 773},
#  {'symbol': 'IOTAETH',
#   'priceChange': '-0.00000330',
#   'priceChangePercent': '-1.791',
#   'weightedAvgPrice': '0.00018421',
#   'prevClosePrice': '0.00018200',
#   'lastPrice': '0.00018100',
#   'lastQty': '183.00000000',
#   'bidPrice': '0.00018080',
#   'bidQty': '2000.00000000',
#   'askPrice': '0.00018120',
#   'askQty': '2000.00000000',
#   'openPrice': '0.00018430',
#   'highPrice': '0.00018590',
#   'lowPrice': '0.00018030',
#   'volume': '42273.00000000',
#   'quoteVolume': '7.78693180',
#   'openTime': 1666621759399,
#   'closeTime': 1666708159399,
#   'firstId': 7718155,
#   'lastId': 7718246,
#   'count': 92},
#  {'symbol': 'LINKBTC',
#   'priceChange': '0.00000360',
#   'priceChangePercent': '1.014',
#   'weightedAvgPrice': '0.00035709',
#   'prevClosePrice': '0.00035500',
#   'lastPrice': '0.00035870',
#   'lastQty': '12.00000000',
#   'bidPrice': '0.00035870',
#   'bidQty': '8.96000000',
#   'askPrice': '0.00035880',
#   'askQty': '67.62000000',
#   'openPrice': '0.00035510',
#   'highPrice': '0.00036040',
#   'lowPrice': '0.00035340',
#   'volume': '272842.94000000',
#   'quoteVolume': '97.43054037',
#   'openTime': 1666621760321,
#   'closeTime': 1666708160321,
#   'firstId': 83007536,
#   'lastId': 83025687,
#   'count': 18152},
#  {'symbol': 'LINKETH',
#   'priceChange': '-0.00006800',
#   'priceChangePercent': '-1.325',
#   'weightedAvgPrice': '0.00511448',
#   'prevClosePrice': '0.00513700',
#   'lastPrice': '0.00506400',
#   'lastQty': '2.85000000',
#   'bidPrice': '0.00506600',
#   'bidQty': '46.01000000',
#   'askPrice': '0.00506800',
#   'askQty': '165.92000000',
#   'openPrice': '0.00513200',
#   'highPrice': '0.00518500',
#   'lowPrice': '0.00503900',
#   'volume': '119426.43000000',
#   'quoteVolume': '610.80387985',
#   'openTime': 1666621758778,
#   'closeTime': 1666708158778,
#   'firstId': 17977444,
#   'lastId': 17980734,
#   'count': 3291},
#  {'symbol': 'XVGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000015',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'XVGETH',
#   'priceChange': '-0.00000012',
#   'priceChangePercent': '-5.085',
#   'weightedAvgPrice': '0.00000229',
#   'prevClosePrice': '0.00000235',
#   'lastPrice': '0.00000224',
#   'lastQty': '13474.00000000',
#   'bidPrice': '0.00000223',
#   'bidQty': '972983.00000000',
#   'askPrice': '0.00000225',
#   'askQty': '2864.00000000',
#   'openPrice': '0.00000236',
#   'highPrice': '0.00000236',
#   'lowPrice': '0.00000223',
#   'volume': '3781546.00000000',
#   'quoteVolume': '8.67332691',
#   'openTime': 1666621679646,
#   'closeTime': 1666708079646,
#   'firstId': 10864224,
#   'lastId': 10864410,
#   'count': 187},
#  {'symbol': 'SALTBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004250',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SALTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00113800',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MDABTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000382',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MDAETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00181150',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MTLBTC',
#   'priceChange': '0.00000075',
#   'priceChangePercent': '1.485',
#   'weightedAvgPrice': '0.00005100',
#   'prevClosePrice': '0.00005022',
#   'lastPrice': '0.00005124',
#   'lastQty': '200.00000000',
#   'bidPrice': '0.00005120',
#   'bidQty': '200.00000000',
#   'askPrice': '0.00005126',
#   'askQty': '10.50000000',
#   'openPrice': '0.00005049',
#   'highPrice': '0.00005162',
#   'lowPrice': '0.00005045',
#   'volume': '34084.00000000',
#   'quoteVolume': '1.73812019',
#   'openTime': 1666621684663,
#   'closeTime': 1666708084663,
#   'firstId': 19814304,
#   'lastId': 19814705,
#   'count': 402},
#  {'symbol': 'MTLETH',
#   'priceChange': '-0.00000800',
#   'priceChangePercent': '-1.095',
#   'weightedAvgPrice': '0.00073177',
#   'prevClosePrice': '0.00072100',
#   'lastPrice': '0.00072240',
#   'lastQty': '9.80000000',
#   'bidPrice': '0.00071950',
#   'bidQty': '215.20000000',
#   'askPrice': '0.00072670',
#   'askQty': '753.90000000',
#   'openPrice': '0.00073040',
#   'highPrice': '0.00073860',
#   'lowPrice': '0.00072240',
#   'volume': '41236.90000000',
#   'quoteVolume': '30.17589882',
#   'openTime': 1666621760691,
#   'closeTime': 1666708160691,
#   'firstId': 3041465,
#   'lastId': 3041643,
#   'count': 179},
#  {'symbol': 'SUBBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000457',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SUBETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00012334',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EOSBTC',
#   'priceChange': '-0.00000070',
#   'priceChangePercent': '-1.264',
#   'weightedAvgPrice': '0.00005523',
#   'prevClosePrice': '0.00005540',
#   'lastPrice': '0.00005470',
#   'lastQty': '177.20000000',
#   'bidPrice': '0.00005470',
#   'bidQty': '7098.30000000',
#   'askPrice': '0.00005480',
#   'askQty': '198.90000000',
#   'openPrice': '0.00005540',
#   'highPrice': '0.00005570',
#   'lowPrice': '0.00005450',
#   'volume': '268340.20000000',
#   'quoteVolume': '14.81910920',
#   'openTime': 1666621758962,
#   'closeTime': 1666708158962,
#   'firstId': 73238228,
#   'lastId': 73241393,
#   'count': 3166},
#  {'symbol': 'SNTBTC',
#   'priceChange': '0.00000004',
#   'priceChangePercent': '2.837',
#   'weightedAvgPrice': '0.00000145',
#   'prevClosePrice': '0.00000142',
#   'lastPrice': '0.00000145',
#   'lastQty': '23887.00000000',
#   'bidPrice': '0.00000144',
#   'bidQty': '296425.00000000',
#   'askPrice': '0.00000145',
#   'askQty': '10511.00000000',
#   'openPrice': '0.00000141',
#   'highPrice': '0.00000147',
#   'lowPrice': '0.00000141',
#   'volume': '16306670.00000000',
#   'quoteVolume': '23.56769013',
#   'openTime': 1666621758909,
#   'closeTime': 1666708158909,
#   'firstId': 12055687,
#   'lastId': 12057989,
#   'count': 2303},
#  {'symbol': 'ETCETH',
#   'priceChange': '-0.00014000',
#   'priceChangePercent': '-0.829',
#   'weightedAvgPrice': '0.01681411',
#   'prevClosePrice': '0.01687000',
#   'lastPrice': '0.01674000',
#   'lastQty': '1.37000000',
#   'bidPrice': '0.01672000',
#   'bidQty': '126.75000000',
#   'askPrice': '0.01675000',
#   'askQty': '0.40000000',
#   'openPrice': '0.01688000',
#   'highPrice': '0.01700000',
#   'lowPrice': '0.01652000',
#   'volume': '3790.82000000',
#   'quoteVolume': '63.73926830',
#   'openTime': 1666621747197,
#   'closeTime': 1666708147197,
#   'firstId': 8422601,
#   'lastId': 8423193,
#   'count': 593},
#  {'symbol': 'ETCBTC',
#   'priceChange': '0.00001800',
#   'priceChangePercent': '1.542',
#   'weightedAvgPrice': '0.00117311',
#   'prevClosePrice': '0.00116600',
#   'lastPrice': '0.00118500',
#   'lastQty': '21.63000000',
#   'bidPrice': '0.00118500',
#   'bidQty': '159.64000000',
#   'askPrice': '0.00118600',
#   'askQty': '36.94000000',
#   'openPrice': '0.00116700',
#   'highPrice': '0.00118700',
#   'lowPrice': '0.00115900',
#   'volume': '46026.19000000',
#   'quoteVolume': '53.99374111',
#   'openTime': 1666621756005,
#   'closeTime': 1666708156005,
#   'firstId': 41882642,
#   'lastId': 41887994,
#   'count': 5353},
#  {'symbol': 'MTHBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000023',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MTHETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004135',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00186480',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTBTC',
#   'priceChange': '0.00000034',
#   'priceChangePercent': '22.368',
#   'weightedAvgPrice': '0.00000192',
#   'prevClosePrice': '0.00000151',
#   'lastPrice': '0.00000186',
#   'lastQty': '1128.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000152',
#   'highPrice': '0.00000245',
#   'lowPrice': '0.00000151',
#   'volume': '51407347.00000000',
#   'quoteVolume': '98.75585834',
#   'openTime': 1666515616984,
#   'closeTime': 1666602016984,
#   'firstId': 15021489,
#   'lastId': 15055397,
#   'count': 33909},
#  {'symbol': 'ZECBTC',
#   'priceChange': '0.00002600',
#   'priceChangePercent': '0.968',
#   'weightedAvgPrice': '0.00270210',
#   'prevClosePrice': '0.00268600',
#   'lastPrice': '0.00271300',
#   'lastQty': '1.03200000',
#   'bidPrice': '0.00271200',
#   'bidQty': '2.24900000',
#   'askPrice': '0.00271400',
#   'askQty': '1.14600000',
#   'openPrice': '0.00268700',
#   'highPrice': '0.00272800',
#   'lowPrice': '0.00267500',
#   'volume': '9440.21500000',
#   'quoteVolume': '25.50838691',
#   'openTime': 1666621755608,
#   'closeTime': 1666708155608,
#   'firstId': 26643191,
#   'lastId': 26648632,
#   'count': 5442},
#  {'symbol': 'ZECETH',
#   'priceChange': '-0.00057000',
#   'priceChangePercent': '-1.464',
#   'weightedAvgPrice': '0.03872594',
#   'prevClosePrice': '0.03888000',
#   'lastPrice': '0.03836000',
#   'lastQty': '0.30000000',
#   'bidPrice': '0.03827000',
#   'bidQty': '1.92800000',
#   'askPrice': '0.03833000',
#   'askQty': '14.00000000',
#   'openPrice': '0.03893000',
#   'highPrice': '0.03920000',
#   'lowPrice': '0.03815000',
#   'volume': '266.60000000',
#   'quoteVolume': '10.32433677',
#   'openTime': 1666621758093,
#   'closeTime': 1666708158093,
#   'firstId': 3513250,
#   'lastId': 3513402,
#   'count': 153},
#  {'symbol': 'BNTBTC',
#   'priceChange': '0.00000001',
#   'priceChangePercent': '0.046',
#   'weightedAvgPrice': '0.00002188',
#   'prevClosePrice': '0.00002179',
#   'lastPrice': '0.00002192',
#   'lastQty': '186.40000000',
#   'bidPrice': '0.00002190',
#   'bidQty': '188.60000000',
#   'askPrice': '0.00002195',
#   'askQty': '997.30000000',
#   'openPrice': '0.00002191',
#   'highPrice': '0.00002214',
#   'lowPrice': '0.00002168',
#   'volume': '114887.70000000',
#   'quoteVolume': '2.51376032',
#   'openTime': 1666621753213,
#   'closeTime': 1666708153213,
#   'firstId': 7775850,
#   'lastId': 7776403,
#   'count': 554},
#  {'symbol': 'ASTBTC',
#   'priceChange': '0.00000032',
#   'priceChangePercent': '4.992',
#   'weightedAvgPrice': '0.00000676',
#   'prevClosePrice': '0.00000643',
#   'lastPrice': '0.00000673',
#   'lastQty': '527.00000000',
#   'bidPrice': '0.00000673',
#   'bidQty': '1290.00000000',
#   'askPrice': '0.00000674',
#   'askQty': '401.00000000',
#   'openPrice': '0.00000641',
#   'highPrice': '0.00000717',
#   'lowPrice': '0.00000628',
#   'volume': '6047887.00000000',
#   'quoteVolume': '40.89031309',
#   'openTime': 1666621724957,
#   'closeTime': 1666708124957,
#   'firstId': 16001571,
#   'lastId': 16011074,
#   'count': 9504},
#  {'symbol': 'ASTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006960',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DASHBTC',
#   'priceChange': '0.00001400',
#   'priceChangePercent': '0.675',
#   'weightedAvgPrice': '0.00208085',
#   'prevClosePrice': '0.00207300',
#   'lastPrice': '0.00208900',
#   'lastQty': '3.00600000',
#   'bidPrice': '0.00208700',
#   'bidQty': '10.00000000',
#   'askPrice': '0.00208900',
#   'askQty': '10.33700000',
#   'openPrice': '0.00207500',
#   'highPrice': '0.00209600',
#   'lowPrice': '0.00205600',
#   'volume': '6837.13000000',
#   'quoteVolume': '14.22702080',
#   'openTime': 1666621743766,
#   'closeTime': 1666708143766,
#   'firstId': 26619793,
#   'lastId': 26622726,
#   'count': 2934},
#  {'symbol': 'DASHETH',
#   'priceChange': '-0.00040000',
#   'priceChangePercent': '-1.336',
#   'weightedAvgPrice': '0.02975386',
#   'prevClosePrice': '0.02994000',
#   'lastPrice': '0.02953000',
#   'lastQty': '0.20000000',
#   'bidPrice': '0.02944000',
#   'bidQty': '4.25000000',
#   'askPrice': '0.02951000',
#   'askQty': '4.26100000',
#   'openPrice': '0.02993000',
#   'highPrice': '0.03022000',
#   'lowPrice': '0.02932000',
#   'volume': '657.80200000',
#   'quoteVolume': '19.57215134',
#   'openTime': 1666621760595,
#   'closeTime': 1666708160595,
#   'firstId': 3806043,
#   'lastId': 3806272,
#   'count': 230},
#  {'symbol': 'OAXBTC',
#   'priceChange': '0.00000094',
#   'priceChangePercent': '10.318',
#   'weightedAvgPrice': '0.00000979',
#   'prevClosePrice': '0.00000910',
#   'lastPrice': '0.00001005',
#   'lastQty': '112.00000000',
#   'bidPrice': '0.00001000',
#   'bidQty': '109237.00000000',
#   'askPrice': '0.00001005',
#   'askQty': '3270.00000000',
#   'openPrice': '0.00000911',
#   'highPrice': '0.00001040',
#   'lowPrice': '0.00000898',
#   'volume': '8916013.00000000',
#   'quoteVolume': '87.31226271',
#   'openTime': 1666621757149,
#   'closeTime': 1666708157149,
#   'firstId': 11829199,
#   'lastId': 11851146,
#   'count': 21948},
#  {'symbol': 'ICNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005742',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BTGBTC',
#   'priceChange': '-0.00005200',
#   'priceChangePercent': '-5.389',
#   'weightedAvgPrice': '0.00102046',
#   'prevClosePrice': '0.00096600',
#   'lastPrice': '0.00091300',
#   'lastQty': '0.60000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00096500',
#   'highPrice': '0.00118600',
#   'lowPrice': '0.00091000',
#   'volume': '81218.04000000',
#   'quoteVolume': '82.87978989',
#   'openTime': 1666515638907,
#   'closeTime': 1666602038907,
#   'firstId': 15327103,
#   'lastId': 15342514,
#   'count': 15412},
#  {'symbol': 'BTGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.05274500',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EVXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000274',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EVXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00062490',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'REQBTC',
#   'priceChange': '-0.00000003',
#   'priceChangePercent': '-0.551',
#   'weightedAvgPrice': '0.00000542',
#   'prevClosePrice': '0.00000544',
#   'lastPrice': '0.00000541',
#   'lastQty': '657.00000000',
#   'bidPrice': '0.00000541',
#   'bidQty': '348.00000000',
#   'askPrice': '0.00000542',
#   'askQty': '5440.00000000',
#   'openPrice': '0.00000544',
#   'highPrice': '0.00000551',
#   'lowPrice': '0.00000535',
#   'volume': '784549.00000000',
#   'quoteVolume': '4.25095971',
#   'openTime': 1666621677024,
#   'closeTime': 1666708077024,
#   'firstId': 13325659,
#   'lastId': 13326429,
#   'count': 771},
#  {'symbol': 'REQETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004995',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'VIBBTC',
#   'priceChange': '0.00000067',
#   'priceChangePercent': '21.406',
#   'weightedAvgPrice': '0.00000372',
#   'prevClosePrice': '0.00000313',
#   'lastPrice': '0.00000380',
#   'lastQty': '100.00000000',
#   'bidPrice': '0.00000378',
#   'bidQty': '19581.00000000',
#   'askPrice': '0.00000380',
#   'askQty': '30382.00000000',
#   'openPrice': '0.00000313',
#   'highPrice': '0.00000425',
#   'lowPrice': '0.00000312',
#   'volume': '45732135.00000000',
#   'quoteVolume': '169.94740366',
#   'openTime': 1666621748102,
#   'closeTime': 1666708148102,
#   'firstId': 10520214,
#   'lastId': 10551582,
#   'count': 31369},
#  {'symbol': 'VIBETH',
#   'priceChange': '0.00000827',
#   'priceChangePercent': '18.196',
#   'weightedAvgPrice': '0.00005324',
#   'prevClosePrice': '0.00004560',
#   'lastPrice': '0.00005372',
#   'lastQty': '94.00000000',
#   'bidPrice': '0.00005341',
#   'bidQty': '1382.00000000',
#   'askPrice': '0.00005373',
#   'askQty': '5584.00000000',
#   'openPrice': '0.00004545',
#   'highPrice': '0.00006087',
#   'lowPrice': '0.00004489',
#   'volume': '7070804.00000000',
#   'quoteVolume': '376.42158065',
#   'openTime': 1666621760282,
# ...
#   'closeTime': 1666708156809,
#   'firstId': 9727662,
#   'lastId': 9729474,
#   'count': 1813},
#  {'symbol': 'TRBBNB',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.51700000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'TRBBTC',
#   'priceChange': '0.00001000',
#   'priceChangePercent': '1.366',
#   'weightedAvgPrice': '0.00073674',
#   'prevClosePrice': '0.00072700',
#   'lastPrice': '0.00074200',
#   'lastQty': '28.31000000',
#   'bidPrice': '0.00074500',
#   'bidQty': '6.94000000',
#   'askPrice': '0.00074600',
#   'askQty': '0.22000000',
#   'openPrice': '0.00073200',
#   'highPrice': '0.00074600',
#   'lowPrice': '0.00073000',
#   'volume': '1837.37000000',
#   'quoteVolume': '1.35366584',
#   'openTime': 1666621759580,
#   'closeTime': 1666708159580,
#   'firstId': 4845873,
#   'lastId': 4846173,
#   'count': 301},
#  {'symbol': 'TRBBUSD',
#   'priceChange': '0.53000000',
#   'priceChangePercent': '3.783',
#   'weightedAvgPrice': '14.29402619',
#   'prevClosePrice': '13.96000000',
#   'lastPrice': '14.54000000',
#   'lastQty': '6.70000000',
#   'bidPrice': '14.53000000',
#   'bidQty': '149.33000000',
#   'askPrice': '14.55000000',
#   'askQty': '3.08000000',
#   'openPrice': '14.01000000',
#   'highPrice': '14.54000000',
#   'lowPrice': '13.97000000',
#   'volume': '8545.21000000',
#   'quoteVolume': '122145.45550000',
#   'openTime': 1666621756871,
#   'closeTime': 1666708156871,
#   'firstId': 3212271,
#   'lastId': 3213019,
#   'count': 749},
#  {'symbol': 'TRBUSDT',
#   'priceChange': '0.54000000',
#   'priceChangePercent': '3.857',
#   'weightedAvgPrice': '14.25510767',
#   'prevClosePrice': '13.99000000',
#   'lastPrice': '14.54000000',
#   'lastQty': '3.05000000',
#   'bidPrice': '14.54000000',
#   'bidQty': '154.07000000',
#   'askPrice': '14.56000000',
#   'askQty': '632.74000000',
#   'openPrice': '14.00000000',
#   'highPrice': '14.55000000',
#   'lowPrice': '13.98000000',
#   'volume': '52689.38000000',
#   'quoteVolume': '751092.78500000',
#   'openTime': 1666621758866,
#   'closeTime': 1666708158866,
#   'firstId': 22853853,
#   'lastId': 22857830,
#   'count': 3978},
#  {'symbol': 'ETHNGN',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '805670.00000000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DOTBIDR',
#   'priceChange': '4313.00',
#   'priceChangePercent': '4.756',
#   'weightedAvgPrice': '93686.28',
#   'prevClosePrice': '91000.00',
#   'lastPrice': '95000.00',
#   'lastQty': '117.22000000',
#   'bidPrice': '94512.00',
#   'bidQty': '16.43000000',
#   'askPrice': '95573.00',
#   'askQty': '16.43000000',
#   'openPrice': '90687.00',
#   'highPrice': '95000.00',
#   'lowPrice': '90687.00',
#   'volume': '3738.12000000',
#   'quoteVolume': '350210567.89',
#   'openTime': 1666621759451,
#   'closeTime': 1666708159451,
#   'firstId': 1274953,
#   'lastId': 1275103,
#   'count': 151},
#  {'symbol': 'LINKAUD',
#   'priceChange': '0.11800000',
#   'priceChangePercent': '1.086',
#   'weightedAvgPrice': '10.93681593',
#   'prevClosePrice': '11.00000000',
#   'lastPrice': '10.97900000',
#   'lastQty': '22.20000000',
#   'bidPrice': '10.96100000',
#   'bidQty': '48.02000000',
#   'askPrice': '10.97800000',
#   'askQty': '11.10000000',
#   'openPrice': '10.86100000',
#   'highPrice': '11.01900000',
#   'lowPrice': '10.79900000',
#   'volume': '4249.78000000',
#   'quoteVolume': '46479.06161000',
#   'openTime': 1666621751260,
#   'closeTime': 1666708151260,
#   'firstId': 536751,
#   'lastId': 536842,
#   'count': 92},
#  {'symbol': 'SXPAUD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '1.86800000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBNB',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00514000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000463',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBUSD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21640000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXUSDT',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21560000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WBTCBTC',
#   'priceChange': '-0.00020000',
#   'priceChangePercent': '-0.020',
#   'weightedAvgPrice': '1.00010061',
#   'prevClosePrice': '1.00010000',
#   'lastPrice': '1.00000000',
#   'lastQty': '0.01931000',
#   'bidPrice': '1.00000000',
#   'bidQty': '2.17260000',
#   'askPrice': '1.00010000',
#   'askQty': '31.79664000',
#   'openPrice': '1.00020000',
#   'highPrice': '1.00050000',
#   'lowPrice': '0.99980000',
#   'volume': '270.05864000',
#   'quoteVolume': '270.08581167',
#   'openTime': 1666621661236,
#   'closeTime': 1666708061236,
#   'firstId': 3159579,
#   'lastId': 3161024,
#   'count': 1446},
#  {'symbol': 'WBTCETH',
#   'priceChange': '-0.33000000',
#   'priceChangePercent': '-2.284',
#   'weightedAvgPrice': '14.26766289',
#   'prevClosePrice': '14.48000000',
#   'lastPrice': '14.12000000',
#   'lastQty': '0.03966000',
#   'bidPrice': '14.11000000',
#   'bidQty': '0.03852000',
#   'askPrice': '14.13000000',
#   'askQty': '0.15926000',
#   'openPrice': '14.45000000',
#   'highPrice': '14.46000000',
#   'lowPrice': '14.06000000',
#   'volume': '10.92175000',
#   'quoteVolume': '155.82784720',
#   'openTime': 1666621685932,
#   'closeTime': 1666708085932,
#   'firstId': 2914250,
#   'lastId': 2915375,
#   'count': 1126},
#  {'symbol': 'SUSHIBNB',
#   'priceChange': '0.00005000',
#   'priceChangePercent': '0.965',
#   'weightedAvgPrice': '0.00524699',
#   'prevClosePrice': '0.00517000',
#   'lastPrice': '0.00523000',
#   'lastQty': '185.50000000',
#   'bidPrice': '0.00522000',
#   'bidQty': '1156.60000000',
#   'askPrice': '0.00523000',
#   'askQty': '158.80000000',
#   'openPrice': '0.00518000',
#   'highPrice': '0.00539000',
#   'lowPrice': '0.00513000',
#   'volume': '66177.00000000',
#   'quoteVolume': '347.22988100',
#   'openTime': 1666621760491,
#   'closeTime': 1666708160491,
#   'firstId': 2704040,
#   'lastId': 2704943,
#   'count': 904},
#  {'symbol': 'SUSHIBTC',
#   'priceChange': '0.00000090',
#   'priceChangePercent': '1.224',
#   'weightedAvgPrice': '0.00007439',
#   'prevClosePrice': '0.00007340',
#   'lastPrice': '0.00007440',
#   'lastQty': '454.50000000',
#   'bidPrice': '0.00007430',
#   'bidQty': '4097.60000000',
#   'askPrice': '0.00007450',
#   'askQty': '1493.40000000',
#   'openPrice': '0.00007350',
#   'highPrice': '0.00007660',
#   'lowPrice': '0.00007240',
#   'volume': '390142.40000000',
#   'quoteVolume': '29.02178852',
#   'openTime': 1666621760363,
#   'closeTime': 1666708160363,
#   'firstId': 17361076,
#   'lastId': 17366343,
#   'count': 5268},
#  {'symbol': 'SUSHIBUSD',
#   'priceChange': '0.04000000',
#   'priceChangePercent': '2.835',
#   'weightedAvgPrice': '1.43799134',
#   'prevClosePrice': '1.41200000',
#   'lastPrice': '1.45100000',
#   'lastQty': '4429.10000000',
#   'bidPrice': '1.45100000',
#   'bidQty': '570.80000000',
#   'askPrice': '1.45300000',
#   'askQty': '1016.60000000',
#   'openPrice': '1.41100000',
#   'highPrice': '1.48100000',
#   'lowPrice': '1.39500000',
#   'volume': '1717170.50000000',
#   'quoteVolume': '2469276.30110000',
#   'openTime': 1666621760589,
#   'closeTime': 1666708160589,
#   'firstId': 9892816,
#   'lastId': 9904890,
#   'count': 12075},
#  {'symbol': 'SUSHIUSDT',
#   'priceChange': '0.04000000',
#   'priceChangePercent': '2.835',
#   'weightedAvgPrice': '1.43387897',
#   'prevClosePrice': '1.41100000',
#   'lastPrice': '1.45100000',
#   'lastQty': '7.80000000',
#   'bidPrice': '1.45100000',
#   'bidQty': '2131.60000000',
#   'askPrice': '1.45200000',
#   'askQty': '8121.50000000',
#   'openPrice': '1.41100000',
#   'highPrice': '1.48100000',
#   'lowPrice': '1.39400000',
#   'volume': '8428897.60000000',
#   'quoteVolume': '12086019.05060000',
#   'openTime': 1666621760583,
#   'closeTime': 1666708160583,
#   'firstId': 87249084,
#   'lastId': 87283116,
#   'count': 34033},
#  {'symbol': 'YFIIBNB',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '4.42000000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'YFIIBTC',
#   'priceChange': '-0.00061000',
#   'priceChangePercent': '-1.003',
#   'weightedAvgPrice': '0.06077517',
#   'prevClosePrice': '0.06041000',
#   'lastPrice': '0.06019000',
#   'lastQty': '0.08520000',
#   'bidPrice': '0.06016000',
#   'bidQty': '0.30000000',
#   'askPrice': '0.06029000',
#   'askQty': '0.30000000',
#   'openPrice': '0.06080000',
#   'highPrice': '0.06206000',
#   'lowPrice': '0.05950000',
#   'volume': '98.86260000',
#   'quoteVolume': '6.00839171',
#   'openTime': 1666621756281,
#   'closeTime': 1666708156281,
#   'firstId': 6988199,
#   'lastId': 6989424,
#   'count': 1226},
#  {'symbol': 'YFIIBUSD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '1192.00000000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1665991241510,
#   'closeTime': 1666077641510,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'YFIIUSDT',
#   'priceChange': '8.40000000',
#   'priceChangePercent': '0.720',
#   'weightedAvgPrice': '1176.57107665',
#   'prevClosePrice': '1168.10000000',
#   'lastPrice': '1175.30000000',
#   'lastQty': '0.01100000',
#   'bidPrice': '1173.70000000',
#   'bidQty': '0.74990000',
#   'askPrice': '1175.30000000',
#   'askQty': '0.30660000',
#   'openPrice': '1166.90000000',
#   'highPrice': '1198.40000000',
#   'lowPrice': '1145.00000000',
#   'volume': '1028.50370000',
#   'quoteVolume': '1210107.70565000',
#   'openTime': 1666621760576,
#   'closeTime': 1666708160576,
#   'firstId': 31467064,
#   'lastId': 31475438,
#   'count': 8375},
#  {'symbol': 'KSMBNB',
#   'priceChange': '0.00280000',
#   'priceChangePercent': '2.247',
#   'weightedAvgPrice': '0.12550162',
#   'prevClosePrice': '0.12300000',
#   'lastPrice': '0.12740000',
#   'lastQty': '3.00000000',
#   'bidPrice': '0.12640000',
#   'bidQty': '2.89200000',
#   'askPrice': '0.12770000',
#   'askQty': '1.07000000',
#   'openPrice': '0.12460000',
#   'highPrice': '0.12750000',
#   'lowPrice': '0.12360000',
#   'volume': '107.75800000',
#   'quoteVolume': '13.52380380',
#   'openTime': 1666621662414,
#   'closeTime': 1666708062414,
#   'firstId': 1117483,
#   'lastId': 1117539,
#   'count': 57},
#  {'symbol': 'KSMBTC',
#   'priceChange': '0.00005900',
#   'priceChangePercent': '3.379',
#   'weightedAvgPrice': '0.00178500',
#   'prevClosePrice': '0.00174500',
#   'lastPrice': '0.00180500',
#   'lastQty': '0.05600000',
#   'bidPrice': '0.00180300',
#   'bidQty': '15.81700000',
#   'askPrice': '0.00180500',
#   'askQty': '8.06000000',
#   'openPrice': '0.00174600',
#   'highPrice': '0.00181200',
#   'lowPrice': '0.00174400',
#   'volume': '2861.10000000',
#   'quoteVolume': '5.10705920',
#   'openTime': 1666621760170,
#   'closeTime': 1666708160170,
#   'firstId': 9587891,
#   'lastId': 9589366,
#   'count': 1476},
#  {'symbol': 'KSMBUSD',
#   'priceChange': '1.60000000',
#   'priceChangePercent': '4.766',
#   'weightedAvgPrice': '34.50518157',
#   'prevClosePrice': '33.59000000',
#   'lastPrice': '35.17000000',
#   'lastQty': '0.28500000',
#   'bidPrice': '35.16000000',
#   'bidQty': '44.40600000',
#   'askPrice': '35.20000000',
#   'askQty': '20.00000000',
#   'openPrice': '33.57000000',
#   'highPrice': '35.28000000',
#   'lowPrice': '33.50000000',
#   'volume': '7955.16100000',
#   'quoteVolume': '274494.27475000',
#   'openTime': 1666621753483,
#   'closeTime': 1666708153483,
#   'firstId': 7180959,
#   'lastId': 7182671,
#   'count': 1713},
#  {'symbol': 'KSMUSDT',
#   'priceChange': '1.64000000',
#   'priceChangePercent': '4.887',
#   'weightedAvgPrice': '34.34248874',
#   'prevClosePrice': '33.57000000',
#   'lastPrice': '35.20000000',
#   'lastQty': '16.46400000',
#   'bidPrice': '35.17000000',
#   'bidQty': '40.91800000',
#   'askPrice': '35.20000000',
#   'askQty': '18.48900000',
#   'openPrice': '33.56000000',
#   'highPrice': '35.25000000',
#   'lowPrice': '33.50000000',
#   'volume': '55995.61300000',
#   'quoteVolume': '1923028.70906000',
#   'openTime': 1666621754723,
#   'closeTime': 1666708154723,
#   'firstId': 59557078,
#   'lastId': 59566790,
#   'count': 9713},
#  {'symbol': 'EGLDBNB',
#   'priceChange': '-0.00230000',
#   'priceChangePercent': '-1.082',
#   'weightedAvgPrice': '0.21193999',
#   'prevClosePrice': '0.21280000',
#   'lastPrice': '0.21020000',
#   'lastQty': '0.31000000',
#   'bidPrice': '0.20930000',
#   'bidQty': '0.55000000',
#   'askPrice': '0.21010000',
#   'askQty': '8.00000000',
#   'openPrice': '0.21250000',
#   'highPrice': '0.21500000',
#   'lowPrice': '0.20880000',
#   'volume': '2088.28000000',
#   'quoteVolume': '442.59004100',
#   'openTime': 1666621760386,
#   'closeTime': 1666708160386,
#   'firstId': 2369345,
#   'lastId': 2370011,
#   'count': 667},
#  ...]

# %%
dfTickers = pd.DataFrame(tickers)
# print(tickers[0])
dfTickers
# Out:
#        symbol    priceChange priceChangePercent weightedAvgPrice  \
# 0      ETHBTC     0.00168200              2.434       0.06975689
# 1      LTCBTC     0.00000900              0.330       0.00272275
# 2      BNBBTC     0.00008700              0.615       0.01416822
# 3      NEOBTC     0.00000600              1.405       0.00042740
# 4     QTUMETH    -0.00002400             -1.201       0.00199430
# ...       ...            ...                ...              ...
# 2113   BTCPLN  1238.00000000              1.293   96526.45238115
# 2114   ETHPLN   238.00000000              3.592    6740.34566099
# 2115  BUSDPLN    -0.01200000             -0.241       4.99052244
# 2116   APTEUR    -0.37530000             -3.848       9.60967991
# 2117   APTTRY    -5.60000000             -3.094     177.32545198
#
#       prevClosePrice       lastPrice       lastQty        bidPrice  \
# 0         0.06911600      0.07079700    3.29700000      0.07079600
# 1         0.00272800      0.00273700    0.43600000      0.00273600
# 2         0.01415000      0.01423700    5.34300000      0.01423600
# 3         0.00042700      0.00043300    0.49000000      0.00043200
# 4         0.00200500      0.00197500   75.30000000      0.00197100
# ...              ...             ...           ...             ...
# 2113  95826.00000000  97011.00000000    0.00518000  96976.00000000
# 2114   6611.00000000   6864.00000000    0.11010000   6864.00000000
# 2115      4.98500000      4.97300000  766.00000000      4.97200000
# 2116      9.71390000      9.37720000    2.74000000      9.37680000
# 2117    181.00000000    175.40000000   52.80000000    175.30000000
#
#             bidQty        askPrice  ...       openPrice       highPrice  \
# 0      14.95160000      0.07079700  ...      0.06911500      0.07112000
# 1       6.56100000      0.00273700  ...      0.00272800      0.00274200
# 2      34.77300000      0.01423700  ...      0.01415000      0.01425000
# 3     430.50000000      0.00043300  ...      0.00042700      0.00043400
# 4      40.70000000      0.00197700  ...      0.00199900      0.00202100
# ...            ...             ...  ...             ...             ...
# 2113    0.01748000  96977.00000000  ...  95773.00000000  97338.00000000
# 2114    1.00930000   6865.00000000  ...   6626.00000000   6884.00000000
# 2115  202.00000000      4.97300000  ...      4.98500000      5.02100000
# 2116   53.59000000      9.39870000  ...      9.75250000      9.86840000
# 2117   11.41000000    175.50000000  ...    181.00000000    183.90000000
#
#             lowPrice           volume         quoteVolume       openTime  \
# 0         0.06908800   83544.93570000       5827.83458055  1666621760630
# 1         0.00270800   44030.36300000        119.88358810  1666621757992
# 2         0.01410400   24419.43800000        345.97987705  1666621755918
# 3         0.00042100   29321.44000000         12.53201760  1666621755814
# 4         0.00196600    1843.50000000          3.67648460  1666621759594
# ...              ...              ...                 ...            ...
# 2113  95676.00000000      25.71681000    2482352.43586000  1666621760187
# 2114   6610.00000000     106.47600000     717685.04460000  1666621759779
# 2115      4.96000000  374664.00000000    1869769.10100000  1666621708522
# 2116      9.18010000   31180.27000000     299632.41424000  1666621743781
# 2117    170.40000000  733907.97000000  130140562.49400000  1666621759999
#
#           closeTime    firstId     lastId   count
# 0     1666708160630  383165931  383346877  180947
# 1     1666708157992   84396764   84409662   12899
# 2     1666708155918  206251441  206292336   40896
# 3     1666708155814   43953473   43955258    1786
# 4     1666708159594    5336528    5336619      92
# ...             ...        ...        ...     ...
# 2113  1666708160187      15735      20274    4540
# 2114  1666708159779       3284       4200     917
# 2115  1666708108522       8003       9797    1795
# 2116  1666708143781       8463       9296     834
# 2117  1666708159999     192307     214081   21775
#
# [2118 rows x 21 columns]

# %%
dfStables = dfTickers[dfTickers.symbol.str.endswith("BUSD")]
dfStables.volume = dfStables.volume.astype(float)
dfStables.priceChangePercent = dfStables.priceChangePercent.astype(float)
dfStables.askPrice = dfStables.askPrice.astype(float)
dfStables
# Out:
# /tmp/ipykernel_176999/1375886947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfStables.volume = dfStables.volume.astype(float)
# /tmp/ipykernel_176999/1375886947.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfStables.priceChangePercent = dfStables.priceChangePercent.astype(float)
# /tmp/ipykernel_176999/1375886947.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfStables.askPrice = dfStables.askPrice.astype(float)
#           symbol   priceChange  priceChangePercent weightedAvgPrice  \
# 613      BNBBUSD    5.50000000               2.021     274.01031299
# 614      BTCBUSD  282.25000000               1.468   19335.67858385
# 631      XRPBUSD    0.00210000               0.466       0.45049902
# 632      ETHBUSD   52.33000000               3.938    1352.89734734
# 633   BCHABCBUSD    0.00000000               0.000       0.00000000
# ...          ...           ...                 ...              ...
# 2102     GMXBUSD    0.44000000               1.224      36.01535187
# 2104    AGIXBUSD    0.00192000               3.907       0.05258431
# 2106     SNTBUSD    0.00106000               3.901       0.02780523
# 2108   POLYXBUSD    0.00030000               0.164       0.18151562
# 2112     APTBUSD   -0.26690000              -2.782       9.36005330
#
#       prevClosePrice       lastPrice         lastQty        bidPrice  \
# 613     272.10000000    277.60000000      0.34000000    277.60000000
# 614   19225.91000000  19506.82000000      0.00513000  19506.80000000
# 631       0.45030000      0.45240000  13026.00000000      0.45230000
# 632    1328.87000000   1381.20000000      1.81600000   1381.20000000
# 633     220.16000000      0.00000000      0.00000000      0.00000000
# ...              ...             ...             ...             ...
# 2102     35.90000000     36.40000000     27.13800000     36.27000000
# 2104      0.04914000      0.05106000   3873.00000000      0.05101000
# 2106      0.02718000      0.02823000   2453.00000000      0.02826000
# 2108      0.18290000      0.18320000  12616.80000000      0.18290000
# 2112      9.58660000      9.32520000     85.69000000      9.32340000
#
#               bidQty     askPrice  ...       openPrice       highPrice  \
# 613     142.82700000    277.70000  ...    272.10000000    277.90000000
# 614       0.00256000  19507.52000  ...  19224.57000000  19527.23000000
# 631   16616.00000000      0.45240  ...      0.45030000      0.45970000
# 632      15.22080000   1381.21000  ...   1328.87000000   1388.36000000
# 633       0.00000000      0.00000  ...      0.00000000      0.00000000
# ...              ...          ...  ...             ...             ...
# 2102      6.01300000     36.40000  ...     35.96000000     36.80000000
# 2104  29473.00000000      0.05112  ...      0.04914000      0.05778000
# 2106   2332.00000000      0.02832  ...      0.02717000      0.02832000
# 2108   4221.60000000      0.18330  ...      0.18290000      0.18600000
# 2112     36.27000000      9.32440  ...      9.59210000      9.75330000
#
#             lowPrice        volume          quoteVolume       openTime  \
# 613     271.60000000  9.427668e+04    25832782.86800000  1666621760758
# 614   19193.83000000  8.822516e+04  1705893318.59313860  1666621760772
# 631       0.44330000  7.921931e+07    35688220.83470000  1666621760714
# 632    1326.18000000  2.688391e+05   363711714.85759300  1666621760606
# 633       0.00000000  0.000000e+00           0.00000000  1665991241510
# ...              ...           ...                  ...            ...
# 2102     35.50000000  1.519640e+04      547303.58518000  1666621740892
# 2104      0.04864000  1.009881e+08     5310391.44063000  1666621756850
# 2106      0.02690000  8.996860e+06      250159.80302000  1666621730057
# 2108      0.17710000  1.119607e+07     2032262.41675000  1666621760386
# 2112      9.05080000  7.053905e+06    66024930.26442700  1666621760773
#
#           closeTime    firstId     lastId    count
# 613   1666708160758  176620082  176679198    59117
# 614   1666708160772  555373788  557269655  1895868
# 631   1666708160714   71644452   71706839    62388
# 632   1666708160606  410697621  410985696   288076
# 633   1666077641510         -1         -1        0
# ...             ...        ...        ...      ...
# 2102  1666708140892     577793     580514     2722
# 2104  1666708156850     462861     489664    26804
# 2106  1666708130057      46179      48200     2022
# 2108  1666708160386     974347     982561     8215
# 2112  1666708160773    1760601    1892864   132264
#
# [369 rows x 21 columns]

# %%
#dfVol = dfStables
dfVol = dfStables[(dfStables.volume > 200000000) & 
                    (dfStables.askPrice > 0)]
#dfVol.priceChangePercent.sort_values(ascending = True, inplace = True) 
dfVol.sort_values('priceChangePercent', axis = 0, ascending = False,
                 inplace = True, na_position ='last') 

dfVol.head(10)
# Out:
# /tmp/ipykernel_176999/3980531895.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfVol.sort_values('priceChangePercent', axis = 0, ascending = False,
#          symbol priceChange  priceChangePercent weightedAvgPrice  \
# 2100    VIBBUSD  0.01367000              22.719       0.07372964
# 1295   REEFBUSD  0.00017800               3.180       0.00573500
# 2054   AKROBUSD  0.00011000               3.161       0.00392732
# 2016   BTTCBUSD  0.00000002               2.597       0.00000077
# 1556    XECBUSD  0.00000057               1.558       0.00003690
# 2047    EPXBUSD  0.00000600               1.279       0.00046968
# 1420   SHIBBUSD  0.00000012               1.212       0.00000995
# 2074  LEVERBUSD  0.00001500               1.046       0.00143723
# 1470    WINBUSD  0.00000090               0.892       0.00010156
# 2056   LUNCBUSD  0.00000191               0.829       0.00023113
#
#      prevClosePrice   lastPrice           lastQty    bidPrice  \
# 2100     0.06017000  0.07384000     9053.00000000  0.07385000
# 1295     0.00559700  0.00577600    17108.00000000  0.00577600
# 2054     0.00348000  0.00359000    13206.00000000  0.00359000
# 2016     0.00000077  0.00000079        18432883.0  0.00000078
# 1556     0.00003660  0.00003715       62778253.00  0.00003715
# 2047     0.00047000  0.00047500  1142048.00000000  0.00047400
# 1420     0.00000990  0.00001002      453229253.00  0.00001002
# 2074     0.00143300  0.00144900   497204.00000000  0.00144800
# 1470     0.00010110  0.00010180   708475.00000000  0.00010170
# 2056     0.00023033  0.00023222  1696403.08000000  0.00023221
#
#                 bidQty      askPrice  ...   openPrice   highPrice    lowPrice  \
# 2100     7083.00000000  7.398000e-02  ...  0.06017000  0.08180000  0.06014000
# 1295     6777.40000000  5.777000e-03  ...  0.00559800  0.00594200  0.00552800
# 2054   184447.00000000  3.600000e-03  ...  0.00348000  0.00448000  0.00345000
# 2016     33158887040.0  7.900000e-07  ...  0.00000077  0.00000079  0.00000076
# 1556       11850286.00  3.718000e-05  ...  0.00003658  0.00003725  0.00003656
# 2047  1845325.00000000  4.750000e-04  ...  0.00046900  0.00047700  0.00046500
# 1420     1840178734.00  1.003000e-05  ...  0.00000990  0.00001006  0.00000982
# 2074  1851121.00000000  1.450000e-03  ...  0.00143400  0.00145100  0.00142200
# 1470  1086419.00000000  1.018000e-04  ...  0.00010090  0.00010270  0.00010050
# 2056  1789922.06000000  2.322200e-04  ...  0.00023031  0.00023399  0.00022876
#
#             volume        quoteVolume       openTime      closeTime   firstId  \
# 2100  4.812070e+08  35479220.12850000  1666621760183  1666708160183   3929379
# 1295  1.069808e+09   6135354.23436540  1666621758358  1666708158358  10832884
# 2054  1.246035e+09   4893582.78490000  1666621717712  1666708117712    847556
# 2016  2.835865e+11    218897.12109044  1666621760184  1666708160184    552051
# 1556  6.458441e+09    238321.03188477  1666621750314  1666708150314  17304313
# 2047  2.655722e+08    124733.61602700  1666621731072  1666708131072   2067689
# 1420  7.872229e+11   7834229.51719130  1666621759469  1666708159469  81659641
# 2074  2.265772e+08    325643.84630000  1666621757252  1666708157252   2980069
# 1470  1.433398e+09    145580.74771900  1666621665840  1666708065840   5490106
# 2056  1.470104e+11  33978787.48464735  1666621760295  1666708160295  80651000
#
#         lastId   count
# 2100   4087151  157773
# 1295  10877318   44435
# 2054    874721   27166
# 2016    553107    1057
# 1556  17306188    1876
# 2047   2068574     886
# 1420  81681713   22073
# 2074   2982218    2150
# 1470   5491054     949
# 2056  80768720  117721
#
# [10 rows x 21 columns]
